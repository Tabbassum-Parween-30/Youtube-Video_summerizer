# %%
pip install youtube-transcript-api
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting youtube-transcript-api
#   Using cached youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Collecting requests (from youtube-transcript-api)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->youtube-transcript-api)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->youtube-transcript-api)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->youtube-transcript-api)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->youtube-transcript-api)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/62.6 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 62.6/62.6 kB 830.7 kB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ------------------------------ --------- 122.9/163.8 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 163.8/163.8 kB 2.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 2.9 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, youtube-transcript-api
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.7 requests-2.31.0 urllib3-2.2.1 youtube-transcript-api-0.6.2
# DEPRECATION: Loading egg at c:\program files\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video_url = "https://www.youtube.com/watch?v=EAD4l202RsY"

# %%
video_id = youtube_video_url.split("=")[1]
video_id
# Out:
# 'EAD4l202RsY'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': 'so there has been a massive rise of MBA',
#   'start': 0.24,
#   'duration': 4.72},
#  {'text': 'chaiwala and bch chaalis in India now',
#   'start': 2.2,
#   'duration': 4.639},
#  {'text': 'please understand that these jobs are',
#   'start': 4.96,
#   'duration': 3.96},
#  {'text': 'not aspirational in nature these are',
#   'start': 6.839,
#   'duration': 5.201},
#  {'text': 'Jobs born out of circumstances so to say',
#   'start': 8.92,
#   'duration': 6.08},
#  {'text': 'no one does an MBA in order to become a',
#   'start': 12.04,
#   'duration': 5.12},
#  {'text': 'chiala seller or a kulcha Wala seller so',
#   'start': 15.0,
#   'duration': 4.359},
#  {'text': 'to say no one does a bch in order to',
#   'start': 17.16,
#   'duration': 4.44},
#  {'text': 'sell snake venom someday this situation',
#   'start': 19.359,
#   'duration': 4.0},
#  {'text': 'is brewing up in India and people are',
#   'start': 21.6,
#   'duration': 4.32},
#  {'text': 'considering their role models as elav or',
#   'start': 23.359,
#   'duration': 4.441},
#  {'text': 'DOA', 'start': 25.92, 'duration': 3.8},
#  {'text': 'because and they eventually want to',
#   'start': 27.8,
#   'duration': 4.439},
#  {'text': 'become these people on the flip side',
#   'start': 29.72,
#   'duration': 5.64},
#  {'text': 'they get to read headlines like these if',
#   'start': 32.239,
#   'duration': 4.721},
#  {'text': 'you do a PhD', 'start': 35.36, 'duration': 3.8},
#  {'text': 'also what is the point of studying',
#   'start': 36.96,
#   'duration': 4.919},
#  {'text': 'working hard like who ended up grinding',
#   'start': 39.16,
#   'duration': 5.919},
#  {'text': "his way through gole CEO so what's the",
#   'start': 41.879,
#   'duration': 5.2},
#  {'text': 'point of studying when jobs are not',
#   'start': 45.079,
#   'duration': 4.041},
#  {'text': 'there in the economy so on this video',
#   'start': 47.079,
#   'duration': 3.561},
#  {'text': "I'm going to speak about three things",
#   'start': 49.12,
#   'duration': 4.239},
#  {'text': 'one is that why is the job situation in',
#   'start': 50.64,
#   'duration': 4.759},
#  {'text': 'India or the unemployment situation in',
#   'start': 53.359,
#   'duration': 4.36},
#  {'text': 'India is so bad number two is it going',
#   'start': 55.399,
#   'duration': 4.241},
#  {'text': 'to change anytime soon and third and the',
#   'start': 57.719,
#   'duration': 4.921},
#  {'text': 'most important point is that can you do',
#   'start': 59.64,
#   'duration': 4.799},
#  {'text': 'something about it how can you save',
#   'start': 62.64,
#   'duration': 3.839},
#  {'text': 'yourself in this unemployment bubble',
#   'start': 64.439,
#   'duration': 4.201},
#  {'text': 'that is getting formed in India forget',
#   'start': 66.479,
#   'duration': 4.121},
#  {'text': 'about politicians one party will sell',
#   'start': 68.64,
#   'duration': 4.159},
#  {'text': 'one data another party will sell another',
#   'start': 70.6,
#   'duration': 4.519},
#  {'text': 'data your life will get bbad', 'start': 72.799, 'duration': 4.64},
#  {'text': "unnecessarily so it's very important to",
#   'start': 75.119,
#   'duration': 3.921},
#  {'text': 'understand take some charge take some',
#   'start': 77.439,
#   'duration': 3.281},
#  {'text': 'action so this is going to be an',
#   'start': 79.04,
#   'duration': 3.48},
#  {'text': "action-packed video I'm honestly going",
#   'start': 80.72,
#   'duration': 5.8},
#  {'text': 'to share my experiences now you might',
#   'start': 82.52,
#   'duration': 6.08},
#  {'text': 'say and all this stuff okay so very',
#   'start': 86.52,
#   'duration': 3.88},
#  {'text': "quick background about me guys if you're",
#   'start': 88.6,
#   'duration': 3.32},
#  {'text': 'new to my channel I just want to', 'start': 90.4, 'duration': 3.2},
#  {'text': 'communicate to you that I have actually',
#   'start': 91.92,
#   'duration': 3.6},
#  {'text': "done corporate jobs I've worked with top",
#   'start': 93.6,
#   'duration': 4.159},
#  {'text': 'tier consulting firms I went to incad',
#   'start': 95.52,
#   'duration': 3.8},
#  {'text': 'which is consistently ranked in top',
#   'start': 97.759,
#   'duration': 3.4},
#  {'text': 'three business schools in the world Ive',
#   'start': 99.32,
#   'duration': 3.92},
#  {'text': 'worked hard I have built startups I do',
#   'start': 101.159,
#   'duration': 4.28},
#  {'text': 'not raise VC fundings currently I run a',
#   'start': 103.24,
#   'duration': 4.96},
#  {'text': 'hedge fund so I have done', 'start': 105.439, 'duration': 5.161},
#  {'text': 'okay you should consider me as your',
#   'start': 108.2,
#   'duration': 4.4},
#  {'text': "nothing like this I'm just telling you",
#   'start': 110.6,
#   'duration': 4.119},
#  {'text': 'that I believe in the power of Education',
#   'start': 112.6,
#   'duration': 4.159},
#  {'text': 'I believe that the Youth of our country',
#   'start': 114.719,
#   'duration': 3.68},
#  {'text': 'needs better education they need to',
#   'start': 116.759,
#   'duration': 3.881},
#  {'text': "upskill themselves that's one way of",
#   'start': 118.399,
#   'duration': 4.281},
#  {'text': "saving yourself saving your career it's",
#   'start': 120.64,
#   'duration': 4.0},
#  {'text': 'absolutely critical just because you',
#   'start': 122.68,
#   'duration': 3.479},
#  {'text': 'know me from YouTube does not make',
#   'start': 124.64,
#   'duration': 3.72},
#  {'text': 'YouTube as 100% of my career if I were',
#   'start': 126.159,
#   'duration': 4.921},
#  {'text': 'to go back in time 10 years and complete',
#   'start': 128.36,
#   'duration': 4.68},
#  {'text': 'my education well I would do exactly the',
#   'start': 131.08,
#   'duration': 4.04},
#  {'text': "same steps that I've done in the past so",
#   'start': 133.04,
#   'duration': 3.199},
#  {'text': "with that Spirit I'm going to", 'start': 135.12, 'duration': 3.119},
#  {'text': "communicate this video I'll be sharp to",
#   'start': 136.239,
#   'duration': 4.08},
#  {'text': 'the point now one way of dealing with',
#   'start': 138.239,
#   'duration': 3.72},
#  {'text': 'high unemployment problem is to',
#   'start': 140.319,
#   'duration': 3.441},
#  {'text': 'constantly upscale yourself but the',
#   'start': 141.959,
#   'duration': 3.721},
#  {'text': 'problem is that traditional business',
#   'start': 143.76,
#   'duration': 4.24},
#  {'text': 'programs they do not give you practical',
#   'start': 145.68,
#   'duration': 4.8},
#  {'text': 'insights but there is a new age business',
#   'start': 148.0,
#   'duration': 4.28},
#  {'text': 'school that is addressing this problem',
#   'start': 150.48,
#   'duration': 3.479},
#  {'text': 'so let me introduce you to Partners of',
#   'start': 152.28,
#   'duration': 3.44},
#  {'text': "today's video which is scaler School of",
#   'start': 153.959,
#   'duration': 3.481},
#  {'text': 'Business they are based out of Bangalore',
#   'start': 155.72,
#   'duration': 3.64},
#  {'text': 'and they offer a management program that',
#   'start': 157.44,
#   'duration': 3.799},
#  {'text': 'is designed by leaders who have built',
#   'start': 159.36,
#   'duration': 4.0},
#  {'text': 'billion doll businesses it exposes',
#   'start': 161.239,
#   'duration': 4.121},
#  {'text': 'students to the industry by making them',
#   'start': 163.36,
#   'duration': 4.36},
#  {'text': 'work on real world projects make them',
#   'start': 165.36,
#   'duration': 4.44},
#  {'text': 'innovate and build a startup while',
#   'start': 167.72,
#   'duration': 4.799},
#  {'text': 'studying and even train them on New Age',
#   'start': 169.8,
#   'duration': 4.64},
#  {'text': 'Technologies such as gen Ai and',
#   'start': 172.519,
#   'duration': 3.601},
#  {'text': 'blockchain these technologies will',
#   'start': 174.44,
#   'duration': 3.28},
#  {'text': 'fundamentally change the business and',
#   'start': 176.12,
#   'duration': 3.44},
#  {'text': 'they educate their students on these',
#   'start': 177.72,
#   'duration': 3.599},
#  {'text': 'topics the founding cohort is getting',
#   'start': 179.56,
#   'duration': 3.56},
#  {'text': 'launched on August of 24 the', 'start': 181.319, 'duration': 3.881},
#  {'text': 'applications are open and you can apply',
#   'start': 183.12,
#   'duration': 4.16},
#  {'text': 'and get even 100% scholarships check the',
#   'start': 185.2,
#   'duration': 3.8},
#  {'text': 'links in description and comment box and',
#   'start': 187.28,
#   'duration': 3.519},
#  {'text': 'apply via these links now with that',
#   'start': 189.0,
#   'duration': 3.36},
#  {'text': "let's move over to the main video so",
#   'start': 190.799,
#   'duration': 2.921},
#  {'text': "okay so let's go question by question",
#   'start': 192.36,
#   'duration': 2.799},
#  {'text': "and let's answer three questions number",
#   'start': 193.72,
#   'duration': 3.28},
#  {'text': 'one why is the unemployment situation',
#   'start': 195.159,
#   'duration': 3.8},
#  {'text': 'bad in India now many people will say',
#   'start': 197.0,
#   'duration': 3.159},
#  {'text': 'that you know what you have political',
#   'start': 198.959,
#   'duration': 2.721},
#  {'text': "inclinations you're showing incorrect",
#   'start': 200.159,
#   'duration': 3.041},
#  {'text': 'data this that so let me just show you',
#   'start': 201.68,
#   'duration': 3.639},
#  {'text': 'three data points you yourself tell me',
#   'start': 203.2,
#   'duration': 3.959},
#  {'text': 'whether these are sensible points or not',
#   'start': 205.319,
#   'duration': 3.681},
#  {'text': 'number one let me ask you that what has',
#   'start': 207.159,
#   'duration': 4.561},
#  {'text': 'been the growth engine of jobs in the',
#   'start': 209.0,
#   'duration': 5.599},
#  {'text': 'last 15 20 years automatic answer comes',
#   'start': 211.72,
#   'duration': 4.64},
#  {'text': 'IT jobs that is how cities like',
#   'start': 214.599,
#   'duration': 4.081},
#  {'text': 'Bangalore Hyderabad so to say flourished',
#   'start': 216.36,
#   'duration': 4.12},
#  {'text': 'because a lot of IT jobs came into the',
#   'start': 218.68,
#   'duration': 4.24},
#  {'text': 'picture that led to the rise of people',
#   'start': 220.48,
#   'duration': 4.479},
#  {'text': 'from lower middle class to upper middle',
#   'start': 222.92,
#   'duration': 3.519},
#  {'text': "class right so that's how migration has",
#   'start': 224.959,
#   'duration': 3.321},
#  {'text': 'happened in the last 20 odd years in',
#   'start': 226.439,
#   'duration': 3.52},
#  {'text': 'India now what is the situation of IT',
#   'start': 228.28,
#   'duration': 3.239},
#  {'text': 'jobs today in India so these are the',
#   'start': 229.959,
#   'duration': 3.721},
#  {'text': 'numbers you can see that it jobs if you',
#   'start': 231.519,
#   'duration': 5.28},
#  {'text': 'look at infosis they cut jobs in 2023',
#   'start': 233.68,
#   'duration': 6.16},
#  {'text': '2024 same applies to Vio except for TCS',
#   'start': 236.799,
#   'duration': 5.08},
#  {'text': 'almost all the other major firms have',
#   'start': 239.84,
#   'duration': 7.239},
#  {'text': 'cut jobs both in 2023 2024 now say ID',
#   'start': 241.879,
#   'duration': 7.961},
#  {'text': 'jobs for example manufacturing uh no',
#   'start': 247.079,
#   'duration': 4.24},
#  {'text': 'manufacturing sector unfortunately',
#   'start': 249.84,
#   'duration': 3.64},
#  {'text': "hasn't grown manufacturing has been a",
#   'start': 251.319,
#   'duration': 3.84},
#  {'text': 'very slow growth sector for India in',
#   'start': 253.48,
#   'duration': 3.2},
#  {'text': 'fact one of the lowest growth sectors in',
#   'start': 255.159,
#   'duration': 3.36},
#  {'text': 'India for the last couple of years again',
#   'start': 256.68,
#   'duration': 4.32},
#  {'text': 'if you look at startups now startups',
#   'start': 258.519,
#   'duration': 4.881},
#  {'text': 'there is startup pivot that happens for',
#   'start': 261.0,
#   'duration': 4.479},
#  {'text': 'example if you go four five years back',
#   'start': 263.4,
#   'duration': 3.92},
#  {'text': 'you yourself would have noticed swiigy',
#   'start': 265.479,
#   'duration': 3.681},
#  {'text': 'pay or zato pay when you used to order',
#   'start': 267.32,
#   'duration': 5.2},
#  {'text': 'stuff D 10 10 rupes you could order like',
#   'start': 269.16,
#   'duration': 5.28},
#  {'text': 'a cupcake or something and the person',
#   'start': 272.52,
#   'duration': 3.48},
#  {'text': 'used to drive on their motorcycle and',
#   'start': 274.44,
#   'duration': 3.039},
#  {'text': 'bring that cupcake for you and you used',
#   'start': 276.0,
#   'duration': 3.6},
#  {'text': 'to feel very happy why did that used to',
#   'start': 277.479,
#   'duration': 4.321},
#  {'text': 'happen because a lot of VC money was',
#   'start': 279.6,
#   'duration': 4.64},
#  {'text': 'there in the ecosystem by and', 'start': 281.8, 'duration': 5.64},
#  {'text': 'startup customer jut no matter how you',
#   'start': 284.24,
#   'duration': 5.679},
#  {'text': 'just get customer you just improve sales',
#   'start': 287.44,
#   'duration': 4.199},
#  {'text': 'okay so sales is revenue generation',
#   'start': 289.919,
#   'duration': 3.481},
#  {'text': "that's it no one was focused on",
#   'start': 291.639,
#   'duration': 4.641},
#  {'text': 'profitability starting 2022 what has',
#   'start': 293.4,
#   'duration': 4.88},
#  {'text': 'happened right so 2020 was a crisis year',
#   'start': 296.28,
#   'duration': 4.72},
#  {'text': '2021 VC funding got crushed what',
#   'start': 298.28,
#   'duration': 6.24},
#  {'text': 'happened in 2023 2024 okay so basically',
#   'start': 301.0,
#   'duration': 5.919},
#  {'text': 'startups started focusing on', 'start': 304.52, 'duration': 4.32},
#  {'text': 'profitability which meant what which',
#   'start': 306.919,
#   'duration': 3.401},
#  {'text': 'meant that they were sensible with their',
#   'start': 308.84,
#   'duration': 3.359},
#  {'text': "hiring numbers so again hiring hasn't",
#   'start': 310.32,
#   'duration': 3.879},
#  {'text': 'really picked up in the startup domain',
#   'start': 312.199,
#   'duration': 5.241},
#  {'text': 'also so grow Eng you guys let me know so',
#   'start': 314.199,
#   'duration': 4.921},
#  {'text': 'this is the first part the second part',
#   'start': 317.44,
#   'duration': 3.8},
#  {'text': 'is that if you take a look at why',
#   'start': 319.12,
#   'duration': 3.76},
#  {'text': 'unemployment situation is so high in',
#   'start': 321.24,
#   'duration': 4.72},
#  {'text': 'India let me Jose that by showing you',
#   'start': 322.88,
#   'duration': 5.039},
#  {'text': 'two data points here number one you take',
#   'start': 325.96,
#   'duration': 4.519},
#  {'text': 'a look at the market cap of a company',
#   'start': 327.919,
#   'duration': 4.681},
#  {'text': 'like State Bank of India now what is the',
#   'start': 330.479,
#   'duration': 3.84},
#  {'text': 'market cap here you will take a look it',
#   'start': 332.6,
#   'duration': 4.68},
#  {'text': 'will be roughly 7 lakh aspas what are',
#   'start': 334.319,
#   'duration': 5.521},
#  {'text': 'the total number of employees at State',
#   'start': 337.28,
#   'duration': 4.6},
#  {'text': 'Bank of India so here is the data they',
#   'start': 339.84,
#   'duration': 5.479},
#  {'text': 'have approximately 240,000 employees for',
#   'start': 341.88,
#   'duration': 7.159},
#  {'text': 'a market cap of 7 lakh CR now what is',
#   'start': 345.319,
#   'duration': 5.561},
#  {'text': 'the situation with adani right or',
#   'start': 349.039,
#   'duration': 3.761},
#  {'text': 'companies like adani so again let me',
#   'start': 350.88,
#   'duration': 3.64},
#  {'text': 'just show you the data exactly same',
#   'start': 352.8,
#   'duration': 3.839},
#  {'text': 'analysis so this is the market cap is',
#   'start': 354.52,
#   'duration': 6.799},
#  {'text': 'roughly 3.2 lakh CR Okay so K ad size p',
#   'start': 356.639,
#   'duration': 6.4},
#  {'text': 'and how many employees does adani group',
#   'start': 361.319,
#   'duration': 3.641},
#  {'text': 'has you guys comment in the comment box',
#   'start': 363.039,
#   'duration': 3.841},
#  {'text': 'let me know this will test you out also',
#   'start': 364.96,
#   'duration': 3.679},
#  {'text': 'I will tell you I will reveal my answer',
#   'start': 366.88,
#   'duration': 3.319},
#  {'text': 'somewhere along the video the short',
#   'start': 368.639,
#   'duration': 3.161},
#  {'text': 'answer is that very Less in fact a',
#   'start': 370.199,
#   'duration': 4.241},
#  {'text': 'fraction of the number of jobs that SBI',
#   'start': 371.8,
#   'duration': 4.6},
#  {'text': 'gives now what is happening if you look',
#   'start': 374.44,
#   'duration': 4.319},
#  {'text': 'at the public sector undertakings or',
#   'start': 376.4,
#   'duration': 5.04},
#  {'text': 'psus as we say what is happening with',
#   'start': 378.759,
#   'duration': 5.16},
#  {'text': 'Indian psus government has decided to',
#   'start': 381.44,
#   'duration': 4.56},
#  {'text': 'divest is that a good decision well',
#   'start': 383.919,
#   'duration': 3.921},
#  {'text': 'there are pros and cons good decision is',
#   'start': 386.0,
#   'duration': 4.599},
#  {'text': 'that see a lot of public money which is',
#   'start': 387.84,
#   'duration': 5.079},
#  {'text': 'there it need not be spent now because',
#   'start': 390.599,
#   'duration': 4.841},
#  {'text': 'psos are generally generally speaking',
#   'start': 392.919,
#   'duration': 4.321},
#  {'text': 'those are ineffective so to say PESA',
#   'start': 395.44,
#   'duration': 4.479},
#  {'text': 'waste and all that stuff so efficiency',
#   'start': 397.24,
#   'duration': 5.32},
#  {'text': 'government has no business in the area',
#   'start': 399.919,
#   'duration': 4.881},
#  {'text': 'of business so to say okay so from that',
#   'start': 402.56,
#   'duration': 4.479},
#  {'text': 'note a step you know public sector',
#   'start': 404.8,
#   'duration': 4.36},
#  {'text': 'undertaking government has reduced its',
#   'start': 407.039,
#   'duration': 4.641},
#  {'text': 'stake but it also means you know what',
#   'start': 409.16,
#   'duration': 4.759},
#  {'text': 'the proportionate amount of employment',
#   'start': 411.68,
#   'duration': 4.359},
#  {'text': 'should have been generated by private',
#   'start': 413.919,
#   'duration': 4.921},
#  {'text': 'players who are coming into the mix is',
#   'start': 416.039,
#   'duration': 4.681},
#  {'text': 'that really happening again go and',
#   'start': 418.84,
#   'duration': 5.4},
#  {'text': 'revisit the story that I just told you',
#   'start': 420.72,
#   'duration': 6.56},
#  {'text': 'SBI versus adani Enterprise how much',
#   'start': 424.24,
#   'duration': 4.84},
#  {'text': 'jobs does it generate why am I picking',
#   'start': 427.28,
#   'duration': 3.96},
#  {'text': 'handpicking adani because this has shown',
#   'start': 429.08,
#   'duration': 3.92},
#  {'text': 'the greatest rise so to say in the',
#   'start': 431.24,
#   'duration': 3.519},
#  {'text': 'private sector in the last 5 10 years',
#   'start': 433.0,
#   'duration': 3.039},
#  {'text': "right so that is the reason why I'm",
#   'start': 434.759,
#   'duration': 3.12},
#  {'text': 'picking this group now third related',
#   'start': 436.039,
#   'duration': 4.361},
#  {'text': 'point we are talking that okay we are A5',
#   'start': 437.879,
#   'duration': 6.6},
#  {'text': 'trillion economy we are like $50',
#   'start': 440.4,
#   'duration': 4.079},
#  {'text': 'trillion whatever right so the bottom',
#   'start': 444.68,
#   'duration': 4.56},
#  {'text': 'line is that okay fine it economy has',
#   'start': 446.759,
#   'duration': 4.761},
#  {'text': 'grown great awesome but how many formal',
#   'start': 449.24,
#   'duration': 5.56},
#  {'text': 'sector employment jobs are we generating',
#   'start': 451.52,
#   'duration': 7.16},
#  {'text': 'right now over 90% of our Workforce just',
#   'start': 454.8,
#   'duration': 5.679},
#  {'text': 'for example 100 L if 100 people are',
#   'start': 458.68,
#   'duration': 4.72},
#  {'text': 'working in India 90 of them work in',
#   'start': 460.479,
#   'duration': 6.12},
#  {'text': 'informal sector', 'start': 463.4, 'duration': 3.199},
#  {'text': 'unorganized so these are unorganized',
#   'start': 474.72,
#   'duration': 5.439},
#  {'text': 'sector jobs formal', 'start': 477.039, 'duration': 4.921},
#  {'text': 'most of the jobs are in unorganized',
#   'start': 480.159,
#   'duration': 4.16},
#  {'text': 'sector so to say which is really sad up',
#   'start': 481.96,
#   'duration': 6.959},
#  {'text': 'now political party a can show you data',
#   'start': 484.319,
#   'duration': 4.6},
#  {'text': 'xss another political party will bash',
#   'start': 489.08,
#   'duration': 3.6},
#  {'text': 'the other', 'start': 491.639, 'duration': 3.68},
#  {'text': 'one I have given you data now you think',
#   'start': 492.68,
#   'duration': 4.56},
#  {'text': 'about it comment below what do you think',
#   'start': 495.319,
#   'duration': 4.481},
#  {'text': 'about it is the job situation in India',
#   'start': 497.24,
#   'duration': 5.239},
#  {'text': 'Rosy is it bad what is happening okay so',
#   'start': 499.8,
#   'duration': 4.2},
#  {'text': 'I have given you my perspective so I',
#   'start': 502.479,
#   'duration': 3.16},
#  {'text': "don't think that the job situation in",
#   'start': 504.0,
#   'duration': 4.24},
#  {'text': 'India is anywhere close to being okay',
#   'start': 505.639,
#   'duration': 4.84},
#  {'text': "right so it's really in bad shape right",
#   'start': 508.24,
#   'duration': 4.159},
#  {'text': 'now and hopefully something is done',
#   'start': 510.479,
#   'duration': 4.04},
#  {'text': 'about it which brings me now to the',
#   'start': 512.399,
#   'duration': 5.161},
#  {'text': 'second question that okay fine situation',
#   'start': 514.519,
#   'duration': 5.32},
#  {'text': 'can it improve going forward and what',
#   'start': 517.56,
#   'duration': 4.76},
#  {'text': 'does the trends look like so for this I',
#   'start': 519.839,
#   'duration': 3.88},
#  {'text': 'would encourage you to take a look at',
#   'start': 522.32,
#   'duration': 3.24},
#  {'text': 'this picture what it does is that it',
#   'start': 523.719,
#   'duration': 4.081},
#  {'text': 'allows you to understand the labor force',
#   'start': 525.56,
#   'duration': 4.64},
#  {'text': 'participation rate labor force', 'start': 527.8, 'duration': 4.479},
#  {'text': 'participation 100 units of Labor is',
#   'start': 530.2,
#   'duration': 4.8},
#  {'text': 'there in the economy then out of which',
#   'start': 532.279,
#   'duration': 5.201},
#  {'text': "let's say if 40% is the labor force",
#   'start': 535.0,
#   'duration': 5.12},
#  {'text': 'participation it means 40% people are',
#   'start': 537.48,
#   'duration': 4.96},
#  {'text': 'participating in our economy okay so',
#   'start': 540.12,
#   'duration': 3.92},
#  {'text': 'what has been the situation like if you',
#   'start': 542.44,
#   'duration': 3.8},
#  {'text': "look at the men's category okay so this",
#   'start': 544.04,
#   'duration': 5.28},
#  {'text': 'has been declining it 3.6 in 2000 now it',
#   'start': 546.24,
#   'duration': 4.92},
#  {'text': 'is somewhere around', 'start': 549.32, 'duration': 4.4},
#  {'text': "77.2 if you look at females again it's",
#   'start': 551.16,
#   'duration': 4.239},
#  {'text': 'not as if that this has gone up this is',
#   'start': 553.72,
#   'duration': 3.2},
#  {'text': 'again a general decline if you look at',
#   'start': 555.399,
#   'duration': 3.241},
#  {'text': "rural again there's a decline if you",
#   'start': 556.92,
#   'duration': 4.56},
#  {'text': "look at Urban again there's a decline",
#   'start': 558.64,
#   'duration': 7.36},
#  {'text': 'now we can go into the nties of',
#   'start': 561.48,
#   'duration': 6.68},
#  {'text': 'it and all that stuff this is what the',
#   'start': 566.0,
#   'duration': 3.6},
#  {'text': 'data tells us to be honest and', 'start': 568.16, 'duration': 3.32},
#  {'text': 'unfortunately this is not moving in the',
#   'start': 569.6,
#   'duration': 3.799},
#  {'text': 'right direction now what is the reason',
#   'start': 571.48,
#   'duration': 3.479},
#  {'text': 'why this is happening so according to me',
#   'start': 573.399,
#   'duration': 3.521},
#  {'text': "there are four major reasons now I'm",
#   'start': 574.959,
#   'duration': 3.761},
#  {'text': 'saying major because there can be many',
#   'start': 576.92,
#   'duration': 3.56},
#  {'text': 'minor reasons also but let me discuss',
#   'start': 578.72,
#   'duration': 3.88},
#  {'text': 'four major ones number one is the spent',
#   'start': 580.48,
#   'duration': 4.72},
#  {'text': 'on capital expenditure now capital',
#   'start': 582.6,
#   'duration': 4.88},
#  {'text': 'expenditure capital expenditure means',
#   'start': 585.2,
#   'duration': 5.0},
#  {'text': 'the productive use of taxpayers money',
#   'start': 587.48,
#   'duration': 4.64},
#  {'text': "that's an easier definition of capital",
#   'start': 590.2,
#   'duration': 3.6},
#  {'text': "expenditure if you're spending on",
#   'start': 592.12,
#   'duration': 4.04},
#  {'text': 'Healthcare then basically lifespan in',
#   'start': 593.8,
#   'duration': 4.4},
#  {'text': 'India improves second if you are',
#   'start': 596.16,
#   'duration': 4.28},
#  {'text': 'spending on education then what what',
#   'start': 598.2,
#   'duration': 3.84},
#  {'text': 'happens that people are more skilled',
#   'start': 600.44,
#   'duration': 4.399},
#  {'text': 'they can do high quality jobs so this is',
#   'start': 602.04,
#   'duration': 4.799},
#  {'text': 'a good productive spent but India',
#   'start': 604.839,
#   'duration': 4.321},
#  {'text': 'capital expenditure yes absolute terms',
#   'start': 606.839,
#   'duration': 4.521},
#  {'text': 'of but in relative terms no it is not',
#   'start': 609.16,
#   'duration': 3.56},
#  {'text': 'really increasing the capital', 'start': 611.36, 'duration': 4.4},
#  {'text': 'expenditure is really bad on top of that',
#   'start': 612.72,
#   'duration': 6.52},
#  {'text': 'critical things for example', 'start': 615.76, 'duration': 3.48},
#  {'text': 'education who goes to', 'start': 623.12, 'duration': 5.32},
#  {'text': 'ISB yes they are relatively well off but',
#   'start': 625.76,
#   'duration': 5.36},
#  {'text': "it's not as if", 'start': 628.44, 'duration': 5.68},
#  {'text': 'know', 'start': 631.12, 'duration': 3.0},
#  {'text': 'something they have to pay 18% GST on',
#   'start': 636.12,
#   'duration': 6.36},
#  {'text': "isb's fees which is absolutely", 'start': 639.16, 'duration': 8.88},
#  {'text': 'rudic why are you pushing people Harding',
#   'start': 642.48,
#   'duration': 5.56},
#  {'text': 'Middle why are you denying them that',
#   'start': 648.519,
#   'duration': 3.88},
#  {'text': 'opportunity and charging like six seven',
#   'start': 650.76,
#   'duration': 4.04},
#  {'text': 'lakhs just in GST fees that can be waved',
#   'start': 652.399,
#   'duration': 4.521},
#  {'text': "off right that's a simple point this is",
#   'start': 654.8,
#   'duration': 5.08},
#  {'text': 'what good capital expenditure could be',
#   'start': 656.92,
#   'duration': 5.359},
#  {'text': "off right that's point one point two",
#   'start': 659.88,
#   'duration': 4.12},
#  {'text': 'what is the issue the second issue why',
#   'start': 662.279,
#   'duration': 3.321},
#  {'text': 'this number is going down and whether or',
#   'start': 664.0,
#   'duration': 3.72},
#  {'text': 'not that will improve the employment',
#   'start': 665.6,
#   'duration': 4.16},
#  {'text': 'engines in the economy are small and',
#   'start': 667.72,
#   'duration': 4.239},
#  {'text': 'medium Enterprises just to help you',
#   'start': 669.76,
#   'duration': 3.96},
#  {'text': 'understand the context for example if',
#   'start': 671.959,
#   'duration': 3.56},
#  {'text': "let's say that you're running a bakery",
#   'start': 673.72,
#   'duration': 3.28},
#  {'text': 'now you will need a baker you will',
#   'start': 675.519,
#   'duration': 3.201},
#  {'text': 'probably need a server right who will go',
#   'start': 677.0,
#   'duration': 4.2},
#  {'text': 'and uh you know serve coffee etc etc',
#   'start': 678.72,
#   'duration': 4.32},
#  {'text': "you'll need a cleaner you'll require at",
#   'start': 681.2,
#   'duration': 3.6},
#  {'text': 'least a team of six seven people to run',
#   'start': 683.04,
#   'duration': 5.76},
#  {'text': 'a small Cafe small Cafe right I mean r',
#   'start': 684.8,
#   'duration': 5.2},
#  {'text': 'cafe', 'start': 688.8, 'duration': 3.279},
#  {'text': 'right I mean an average small gafe how',
#   'start': 690.0,
#   'duration': 4.079},
#  {'text': 'much business would it do not much right',
#   'start': 692.079,
#   'duration': 3.88},
#  {'text': 'I mean maybe they will make a profit of',
#   'start': 694.079,
#   'duration': 5.401},
#  {'text': 'a lakh a month maybe average now for',
#   'start': 695.959,
#   'duration': 5.88},
#  {'text': 'generating a profit of one lakh someone',
#   'start': 699.48,
#   'duration': 3.96},
#  {'text': 'is getting an employment or 10 people',
#   'start': 701.839,
#   'duration': 3.721},
#  {'text': 'are getting employment now there are big',
#   'start': 703.44,
#   'duration': 3.8},
#  {'text': "big companies again I'll not get into",
#   'start': 705.56,
#   'duration': 4.04},
#  {'text': 'name taking they are generating millions',
#   'start': 707.24,
#   'duration': 4.24},
#  {'text': "and billions of profit they're", 'start': 709.6, 'duration': 4.08},
#  {'text': 'recruiting like a profit to employee',
#   'start': 711.48,
#   'duration': 5.479},
#  {'text': 'ratio basically they would be hiring one',
#   'start': 713.68,
#   'duration': 5.599},
#  {'text': 'person so this simple analysis tells you',
#   'start': 716.959,
#   'duration': 3.921},
#  {'text': 'that the growth engine in the economy',
#   'start': 719.279,
#   'duration': 3.441},
#  {'text': 'are small and medium Enterprises these',
#   'start': 720.88,
#   'duration': 4.12},
#  {'text': 'are not Fortune 500 companies now what',
#   'start': 722.72,
#   'duration': 4.16},
#  {'text': 'has happened in India in India the',
#   'start': 725.0,
#   'duration': 4.2},
#  {'text': 'corporate taxes are lower compared to',
#   'start': 726.88,
#   'duration': 4.84},
#  {'text': 'personal income taxes compliance on',
#   'start': 729.2,
#   'duration': 4.92},
#  {'text': 'small', 'start': 731.72, 'duration': 2.4},
#  {'text': 'businesses', 'start': 738.48, 'duration': 3.0},
#  {'text': 'alsoit is getting', 'start': 742.279, 'duration': 7.36},
#  {'text': 'made someone has to go appoint a ca g',
#   'start': 744.68,
#   'duration': 7.48},
#  {'text': 'str1 and all that right accountant',
#   'start': 749.639,
#   'duration': 4.841},
#  {'text': 'maintain so many headaches are there and',
#   'start': 752.16,
#   'duration': 4.0},
#  {'text': 'this is called as high compliance cost',
#   'start': 754.48,
#   'duration': 3.76},
#  {'text': 'so if the compliance cost for small',
#   'start': 756.16,
#   'duration': 4.08},
#  {'text': 'businesses can go down it can be a game',
#   'start': 758.24,
#   'duration': 3.92},
#  {'text': 'changer it would allow for these small',
#   'start': 760.24,
#   'duration': 5.48},
#  {'text': 'businesses to flourish', 'start': 762.16, 'duration': 3.56},
#  {'text': 'entrepreneur so why are you pushing them',
#   'start': 768.959,
#   'duration': 3.761},
#  {'text': 'for like so many compliances make life',
#   'start': 771.0,
#   'duration': 3.519},
#  {'text': 'easy on them they will focus on growing',
#   'start': 772.72,
#   'duration': 3.52},
#  {'text': 'their business maybe just having one',
#   'start': 774.519,
#   'duration': 3.44},
#  {'text': 'Bakery they can have three four bakeries',
#   'start': 776.24,
#   'duration': 3.399},
#  {'text': 'and they can add more jobs', 'start': 777.959, 'duration': 3.56},
#  {'text': 'this is point two number three the',
#   'start': 779.639,
#   'duration': 3.961},
#  {'text': 'critical problem in India is lack of',
#   'start': 781.519,
#   'duration': 4.521},
#  {'text': 'quality jobs now I will name an', 'start': 783.6, 'duration': 5.4},
#  {'text': 'economist Dr', 'start': 786.04, 'duration': 2.96},
#  {'text': 'a if your mindset is poor if you cannot',
#   'start': 792.0,
#   'duration': 4.959},
#  {'text': 'separate people from political', 'start': 795.32, 'duration': 4.0},
#  {'text': "ideologies their ideas then you're",
#   'start': 796.959,
#   'duration': 4.44},
#  {'text': 'already mentally bankrupt nothing in the',
#   'start': 799.32,
#   'duration': 6.24},
#  {'text': 'world can save you now Congress',
#   'start': 801.399,
#   'duration': 4.161},
#  {'text': 'work of all the economists including Dr',
#   'start': 809.279,
#   'duration': 4.041},
#  {'text': "Rajan that does not mean that I'm XYZ",
#   'start': 811.16,
#   'duration': 4.52},
#  {'text': 'party supporter so on that note Dr Rajan',
#   'start': 813.32,
#   'duration': 4.24},
#  {'text': 'had said that you know what the service',
#   'start': 815.68,
#   'duration': 3.959},
#  {'text': 'sector economy should be pushed service',
#   'start': 817.56,
#   'duration': 4.839},
#  {'text': 'sector jobs should be created right',
#   'start': 819.639,
#   'duration': 5.56},
#  {'text': 'because see think about it India land',
#   'start': 822.399,
#   'duration': 5.201},
#  {'text': 'prices in land G those are one of the',
#   'start': 825.199,
#   'duration': 4.561},
#  {'text': 'highest in the world for example just',
#   'start': 827.6,
#   'duration': 4.239},
#  {'text': 'for context per square meter rate of',
#   'start': 829.76,
#   'duration': 5.24},
#  {'text': 'real estate of Dubai is half the rate',
#   'start': 831.839,
#   'duration': 5.321},
#  {'text': "that of Mumbai okay this I'm not kidding",
#   'start': 835.0,
#   'duration': 4.72},
#  {'text': 'this is actually the fact argument',
#   'start': 837.16,
#   'duration': 4.44},
#  {'text': 'average', 'start': 839.72, 'duration': 4.52},
#  {'text': 'income the per cap income of Dubai is',
#   'start': 841.6,
#   'duration': 4.76},
#  {'text': 'higher than Mumbai but despite that the',
#   'start': 844.24,
#   'duration': 4.0},
#  {'text': 'real estate of Mumbai is double that of',
#   'start': 846.36,
#   'duration': 3.839},
#  {'text': 'Dubai now why because there is lot of',
#   'start': 848.24,
#   'duration': 3.719},
#  {'text': 'black money in the real estate market',
#   'start': 850.199,
#   'duration': 3.121},
#  {'text': 'now when there is lot of black money in',
#   'start': 851.959,
#   'duration': 2.841},
#  {'text': 'the real estate market the cost of',
#   'start': 853.32,
#   'duration': 3.6},
#  {'text': 'commercial shops go up cost of', 'start': 854.8, 'duration': 5.159},
#  {'text': 'everything around you goes', 'start': 856.92, 'duration': 3.039},
#  {'text': 'up', 'start': 861.92, 'duration': 3.0},
#  {'text': "off that's how it will be right",
#   'start': 866.36,
#   'duration': 4.68},
#  {'text': 'similarly', 'start': 868.6, 'duration': 2.44},
#  {'text': 'now how he hire like two more people to',
#   'start': 872.6,
#   'duration': 4.12},
#  {'text': 'do that so everything goes into real',
#   'start': 875.0,
#   'duration': 4.199},
#  {'text': 'estate so to say in simple words the',
#   'start': 876.72,
#   'duration': 4.919},
#  {'text': 'cost of capital in India is very very',
#   'start': 879.199,
#   'duration': 5.0},
#  {'text': 'high okay and therefore manufacturing',
#   'start': 881.639,
#   'duration': 4.721},
#  {'text': 'jobs', 'start': 884.199, 'duration': 3.721},
#  {'text': 'manufactur', 'start': 886.36, 'duration': 4.039},
#  {'text': 'labal so therefore the capital goes up',
#   'start': 887.92,
#   'duration': 4.039},
#  {'text': 'very very high if you put that factory',
#   'start': 890.399,
#   'duration': 3.88},
#  {'text': 'somewhere in America maybe compared to',
#   'start': 891.959,
#   'duration': 4.641},
#  {'text': 'that in India therefore so much of FDI',
#   'start': 894.279,
#   'duration': 4.041},
#  {'text': 'Capital does not come to India and stay',
#   'start': 896.6,
#   'duration': 4.44},
#  {'text': 'in India and jobs therefore focusing on',
#   'start': 898.32,
#   'duration': 4.36},
#  {'text': 'manufacturing sector yes it should be',
#   'start': 901.04,
#   'duration': 3.2},
#  {'text': 'done no one is against', 'start': 902.68, 'duration': 4.599},
#  {'text': 'that India make XYZ and all that stuff',
#   'start': 904.24,
#   'duration': 4.48},
#  {'text': 'practically what has been done that',
#   'start': 907.279,
#   'duration': 3.321},
#  {'text': 'needs to be seen but what can be done',
#   'start': 908.72,
#   'duration': 3.919},
#  {'text': 'are service sector quality jobs service',
#   'start': 910.6,
#   'duration': 3.919},
#  {'text': 'sector it grew in India because we were',
#   'start': 912.639,
#   'duration': 3.76},
#  {'text': 'exporting so much stuff companies like',
#   'start': 914.519,
#   'duration': 5.76},
#  {'text': 'infosis TCS they exported stuff',
#   'start': 916.399,
#   'duration': 6.281},
#  {'text': 'Industries which are truly exporting to',
#   'start': 920.279,
#   'duration': 5.0},
#  {'text': 'the world and it is one such industry',
#   'start': 922.68,
#   'duration': 4.44},
#  {'text': 'and more such Industries need to be',
#   'start': 925.279,
#   'duration': 3.721},
#  {'text': 'created and they are most likely to',
#   'start': 927.12,
#   'duration': 4.12},
#  {'text': 'succeed in service sector jobs so focus',
#   'start': 929.0,
#   'duration': 4.48},
#  {'text': 'on service sector is the key fourth',
#   'start': 931.24,
#   'duration': 4.32},
#  {'text': 'point is that we have inability to',
#   'start': 933.48,
#   'duration': 4.839},
#  {'text': 'retain Talent now why is that', 'start': 935.56, 'duration': 5.32},
#  {'text': 'becauseas number one is the hitting of',
#   'start': 938.319,
#   'duration': 5.481},
#  {'text': 'glass ceiling for example if you want if',
#   'start': 940.88,
#   'duration': 5.36},
#  {'text': 'you get like a one CR job okay now very',
#   'start': 943.8,
#   'duration': 4.44},
#  {'text': 'few one CR jobs are there now if someone',
#   'start': 946.24,
#   'duration': 4.76},
#  {'text': 'is extremely smart bright intelligent',
#   'start': 948.24,
#   'duration': 4.56},
#  {'text': 'they are extremely capable people would',
#   'start': 951.0,
#   'duration': 4.519},
#  {'text': 'they not want to earn one CR they would',
#   'start': 952.8,
#   'duration': 4.44},
#  {'text': 'where would they find such opportunities',
#   'start': 955.519,
#   'duration': 4.12},
#  {'text': 'most likely outside India so those are',
#   'start': 957.24,
#   'duration': 4.599},
#  {'text': 'high paying jobs now we need those type',
#   'start': 959.639,
#   'duration': 3.801},
#  {'text': 'of high paying jobs these are private',
#   'start': 961.839,
#   'duration': 4.48},
#  {'text': 'Equity VC Consulting Investment Banking',
#   'start': 963.44,
#   'duration': 5.079},
#  {'text': 'front-end jobs these are the type of',
#   'start': 966.319,
#   'duration': 4.241},
#  {'text': 'jobs that we our politician should focus',
#   'start': 968.519,
#   'duration': 3.88},
#  {'text': 'on bringing in the Indian economy',
#   'start': 970.56,
#   'duration': 3.68},
#  {'text': 'high-end artificial intelligence machine',
#   'start': 972.399,
#   'duration': 5.601},
#  {'text': 'learning ET for this we cannot have the',
#   'start': 974.24,
#   'duration': 6.76},
#  {'text': 'mindset', 'start': 978.0, 'duration': 3.0},
#  {'text': 'Mig that is not the way to retain Talent',
#   'start': 983.639,
#   'duration': 5.041},
#  {'text': 'the way to retain Talent is very simple',
#   'start': 986.8,
#   'duration': 3.599},
#  {'text': 'that you give them recognition you give',
#   'start': 988.68,
#   'duration': 3.56},
#  {'text': 'them appreciation if someone is a high',
#   'start': 990.399,
#   'duration': 3.641},
#  {'text': 'performer then give them more', 'start': 992.24, 'duration': 3.76},
#  {'text': 'opportunities so that is how you retain',
#   'start': 994.04,
#   'duration': 4.239},
#  {'text': 'Talent they also feel loyal to you India',
#   'start': 996.0,
#   'duration': 4.279},
#  {'text': 'May the net millionaire migration in the',
#   'start': 998.279,
#   'duration': 4.201},
#  {'text': 'world is number two right China May',
#   'start': 1000.279,
#   'duration': 3.36},
#  {'text': 'there are 10,000 millionaires who',
#   'start': 1002.48,
#   'duration': 3.159},
#  {'text': "migrate India May it's 8 and a half",
#   'start': 1003.639,
#   'duration': 4.241},
#  {'text': '9,000 ASP now you say China number one',
#   'start': 1005.639,
#   'duration': 4.361},
#  {'text': "in China no it's not like that China",
#   'start': 1007.88,
#   'duration': 3.639},
#  {'text': 'number of rich people are also very high',
#   'start': 1010.0,
#   'duration': 3.48},
#  {'text': 'right so number of millionaires in China',
#   'start': 1011.519,
#   'duration': 3.961},
#  {'text': 'are much more compared to that of number',
#   'start': 1013.48,
#   'duration': 4.96},
#  {'text': 'of millionaires in India so adjustment',
#   'start': 1015.48,
#   'duration': 4.68},
#  {'text': 'then India will be far far higher so',
#   'start': 1018.44,
#   'duration': 3.92},
#  {'text': 'this is not a good situation in India',
#   'start': 1020.16,
#   'duration': 4.039},
#  {'text': 'and something needs to be done about it',
#   'start': 1022.36,
#   'duration': 4.719},
#  {'text': 'so then comes the final', 'start': 1024.199, 'duration': 2.88},
#  {'text': 'point but yes if some politician feels',
#   'start': 1036.6,
#   'duration': 4.28},
#  {'text': "that I can be of help I'll be more than",
#   'start': 1039.319,
#   'duration': 3.76},
#  {'text': 'happy to give my services for free but I',
#   'start': 1040.88,
#   'duration': 4.24},
#  {'text': 'have no interest in joining politics now',
#   'start': 1043.079,
#   'duration': 4.0},
#  {'text': 'so again I will give you four specific',
#   'start': 1045.12,
#   'duration': 3.52},
#  {'text': 'pieces of advice and these are some',
#   'start': 1047.079,
#   'duration': 3.201},
#  {'text': 'things that you yourself can do so',
#   'start': 1048.64,
#   'duration': 3.52},
#  {'text': "you're not dependent on any politician",
#   'start': 1050.28,
#   'duration': 4.44},
#  {'text': 'per se number one there should be',
#   'start': 1052.16,
#   'duration': 4.879},
#  {'text': 'apprentiship based model now this can be',
#   'start': 1054.72,
#   'duration': 5.4},
#  {'text': 'done by institutes at an Institute',
#   'start': 1057.039,
#   'duration': 6.161},
#  {'text': 'level for example when I went to NC',
#   'start': 1060.12,
#   'duration': 4.2},
#  {'text': 'there was a program called as', 'start': 1063.2, 'duration': 3.76},
#  {'text': 'entrepreneur in Residence they used to',
#   'start': 1064.32,
#   'duration': 4.599},
#  {'text': 'invite entrepreneurs they used to you',
#   'start': 1066.96,
#   'duration': 4.4},
#  {'text': 'know let the MBA cohort work with them',
#   'start': 1068.919,
#   'duration': 4.681},
#  {'text': 'on some startup and that was very nice',
#   'start': 1071.36,
#   'duration': 4.08},
#  {'text': 'right so that was facilitated by the',
#   'start': 1073.6,
#   'duration': 3.64},
#  {'text': 'educational institute itself so this can',
#   'start': 1075.44,
#   'duration': 3.599},
#  {'text': 'be done at an educational institute',
#   'start': 1077.24,
#   'duration': 4.88},
#  {'text': 'level College this can be done or made',
#   'start': 1079.039,
#   'duration': 5.401},
#  {'text': 'as a part of Curriculum by the national',
#   'start': 1082.12,
#   'duration': 4.12},
#  {'text': 'state government so to say this can be',
#   'start': 1084.44,
#   'duration': 3.44},
#  {'text': 'done third you yourself can do it for',
#   'start': 1086.24,
#   'duration': 3.08},
#  {'text': 'example you start approaching people on',
#   'start': 1087.88,
#   'duration': 4.2},
#  {'text': 'LinkedIn whom you look up to experiment',
#   'start': 1089.32,
#   'duration': 5.0},
#  {'text': 'but do it on some other people first go',
#   'start': 1092.08,
#   'duration': 4.28},
#  {'text': 'and engage with them on social media',
#   'start': 1094.32,
#   'duration': 3.719},
#  {'text': 'platforms cultivate a relationship how',
#   'start': 1096.36,
#   'duration': 4.199},
#  {'text': "do you do it for example I'm writing",
#   'start': 1098.039,
#   'duration': 4.241},
#  {'text': 'some post some other person is writing',
#   'start': 1100.559,
#   'duration': 4.721},
#  {'text': 'some post engage on that post', 'start': 1102.28, 'duration': 5.16},
#  {'text': "postage no that's not engagement",
#   'start': 1105.28,
#   'duration': 4.12},
#  {'text': 'engagement means that you write content',
#   'start': 1107.44,
#   'duration': 3.76},
#  {'text': 'you write something nice you give a',
#   'start': 1109.4,
#   'duration': 4.2},
#  {'text': 'useful point of view politely so all',
#   'start': 1111.2,
#   'duration': 5.08},
#  {'text': 'that is called as engagement so everyone',
#   'start': 1113.6,
#   'duration': 5.199},
#  {'text': 'reads like at least posts and all that',
#   'start': 1116.28,
#   'duration': 5.08},
#  {'text': 'stuff so say you are able to cultivate a',
#   'start': 1118.799,
#   'duration': 4.921},
#  {'text': 'relationship then ask to work on some',
#   'start': 1121.36,
#   'duration': 4.24},
#  {'text': 'practical project with them', 'start': 1123.72, 'duration': 4.56},
#  {'text': 'so relationship this is very important',
#   'start': 1125.6,
#   'duration': 4.6},
#  {'text': 'apprentiship is extremely critical',
#   'start': 1128.28,
#   'duration': 3.56},
#  {'text': 'important because you learn things',
#   'start': 1130.2,
#   'duration': 3.64},
#  {'text': 'really really fast now second key point',
#   'start': 1131.84,
#   'duration': 3.56},
#  {'text': 'that we can Institute something called',
#   'start': 1133.84,
#   'duration': 4.6},
#  {'text': 'as a reward system now reward system for',
#   'start': 1135.4,
#   'duration': 4.399},
#  {'text': 'example', 'start': 1138.44, 'duration': 3.04},
#  {'text': 'basic minimum', 'start': 1139.799, 'duration': 3.801},
#  {'text': 'guarantee for example if you go to a',
#   'start': 1141.48,
#   'duration': 4.04},
#  {'text': 'college okay and if that college cannot',
#   'start': 1143.6,
#   'duration': 4.439},
#  {'text': 'provide you three lakh four L job',
#   'start': 1145.52,
#   'duration': 4.8},
#  {'text': "then right I mean that's plain and",
#   'start': 1148.039,
#   'duration': 4.161},
#  {'text': 'simple right college is charging you',
#   'start': 1150.32,
#   'duration': 4.719},
#  {'text': 'lacks and lacks of', 'start': 1152.2, 'duration': 5.32},
#  {'text': "fees right there's no reward at the end",
#   'start': 1155.039,
#   'duration': 5.321},
#  {'text': 'no so make things accountable make',
#   'start': 1157.52,
#   'duration': 4.519},
#  {'text': 'colleges', 'start': 1160.36, 'duration': 4.52},
#  {'text': "accountable College if you're charging",
#   'start': 1162.039,
#   'duration': 4.401},
#  {'text': 'so much fees this is the minimum',
#   'start': 1164.88,
#   'duration': 3.24},
#  {'text': 'guarantee that you need to give now you',
#   'start': 1166.44,
#   'duration': 3.52},
#  {'text': 'might say that this is a ludicrous idea',
#   'start': 1168.12,
#   'duration': 4.24},
#  {'text': 'right how can you give guarantee',
#   'start': 1169.96,
#   'duration': 4.599},
#  {'text': 'interview okay fine what you can do is',
#   'start': 1172.36,
#   'duration': 3.72},
#  {'text': 'that for example the college placement',
#   'start': 1174.559,
#   'duration': 3.841},
#  {'text': 'cell needs to be made accountable that',
#   'start': 1176.08,
#   'duration': 3.8},
#  {'text': 'these are the number of companies that',
#   'start': 1178.4,
#   'duration': 2.92},
#  {'text': 'should visit your campus if you are',
#   'start': 1179.88,
#   'duration': 3.4},
#  {'text': 'charging fees X and this is called as',
#   'start': 1181.32,
#   'duration': 5.52},
#  {'text': 'creating a merit oriented', 'start': 1183.28, 'duration': 3.56},
#  {'text': 'program why are they charging it just',
#   'start': 1187.4,
#   'duration': 4.6},
#  {'text': 'does not make any sense and student',
#   'start': 1190.12,
#   'duration': 3.72},
#  {'text': 'should write with the education Ministry',
#   'start': 1192.0,
#   'duration': 3.799},
#  {'text': "with this idea if you're watching this",
#   'start': 1193.84,
#   'duration': 3.719},
#  {'text': 'video please go collect signatures from',
#   'start': 1195.799,
#   'duration': 3.841},
#  {'text': 'your class and write it to the Min maybe',
#   'start': 1197.559,
#   'duration': 5.0},
#  {'text': 'they will take a look at otherwise go on',
#   'start': 1199.64,
#   'duration': 5.279},
#  {'text': 'Twitter you', 'start': 1202.559, 'duration': 5.401},
#  {'text': "go this is that I've suggested and here",
#   'start': 1204.919,
#   'duration': 4.801},
#  {'text': 'are like 50 signs is that stuff I will',
#   'start': 1207.96,
#   'duration': 3.28},
#  {'text': "try to make it viral right so that's all",
#   'start': 1209.72,
#   'duration': 3.36},
#  {'text': 'I can do for you creating this reward',
#   'start': 1211.24,
#   'duration': 4.04},
#  {'text': 'system is critical number three that',
#   'start': 1213.08,
#   'duration': 4.16},
#  {'text': 'what can you do so there are two things',
#   'start': 1215.28,
#   'duration': 3.879},
#  {'text': 'that you need to differentiate on one is',
#   'start': 1217.24,
#   'duration': 3.6},
#  {'text': 'called as entrepreneurship now',
#   'start': 1219.159,
#   'duration': 3.52},
#  {'text': 'entrepreneurship is really tough right',
#   'start': 1220.84,
#   'duration': 4.3},
#  {'text': 'entrepr', 'start': 1222.679, 'duration': 5.62},
#  {'text': '[Music]', 'start': 1225.14, 'duration': 3.159},
#  {'text': "funding we don't know how to create like",
#   'start': 1228.919,
#   'duration': 3.201},
#  {'text': "a pitch deck we don't know how to get",
#   'start': 1230.76,
#   'duration': 4.039},
#  {'text': 'featured on CH Tang or whatever right so',
#   'start': 1232.12,
#   'duration': 4.32},
#  {'text': 'right I mean honestly like', 'start': 1234.799, 'duration': 3.961},
#  {'text': 'entrepreneurship right basically what',
#   'start': 1236.44,
#   'duration': 5.119},
#  {'text': 'you should learn is how to build small',
#   'start': 1238.76,
#   'duration': 4.36},
#  {'text': 'profitable businesses now what is the',
#   'start': 1241.559,
#   'duration': 4.081},
#  {'text': 'meaning of small profitable businesses',
#   'start': 1243.12,
#   'duration': 4.799},
#  {'text': 'examp right for example I have built at',
#   'start': 1245.64,
#   'duration': 5.0},
#  {'text': 'least 15 small profitable businesses so',
#   'start': 1247.919,
#   'duration': 5.721},
#  {'text': 'to say and video you guys go and watch',
#   'start': 1250.64,
#   'duration': 5.44},
#  {'text': 'it that how did I build my Airbnb so to',
#   'start': 1253.64,
#   'duration': 4.84},
#  {'text': 'say I have used that as a case study you',
#   'start': 1256.08,
#   'duration': 4.28},
#  {'text': 'can can apply that', 'start': 1258.48, 'duration': 5.0},
#  {'text': 'now for example Airbnb there is a',
#   'start': 1260.36,
#   'duration': 6.24},
#  {'text': 'concept called as Arbitrage now AR',
#   'start': 1263.48,
#   'duration': 5.36},
#  {'text': "basically for example you're not buying",
#   'start': 1266.6,
#   'duration': 4.199},
#  {'text': "any property You're simply going and",
#   'start': 1268.84,
#   'duration': 3.319},
#  {'text': "speaking with a homeowner and you're",
#   'start': 1270.799,
#   'duration': 2.561},
#  {'text': 'telling them that you know what boss',
#   'start': 1272.159,
#   'duration': 3.081},
#  {'text': 'your property is vacant can I please',
#   'start': 1273.36,
#   'duration': 4.52},
#  {'text': 'list this on Airbnb and if you have',
#   'start': 1275.24,
#   'duration': 4.64},
#  {'text': 'ability to Market it if you have ability',
#   'start': 1277.88,
#   'duration': 5.64},
#  {'text': 'to operate it you can do it and',
#   'start': 1279.88,
#   'duration': 3.64},
#  {'text': 'Airbnb all that no people are extreme',
#   'start': 1285.84,
#   'duration': 4.6},
#  {'text': 'entrepreneurial westerners are very',
#   'start': 1288.799,
#   'duration': 3.441},
#  {'text': 'entrepreneurial in terms of running this',
#   'start': 1290.44,
#   'duration': 4.44},
#  {'text': 'Airbnb Arbitrage but in our country the',
#   'start': 1292.24,
#   'duration': 4.919},
#  {'text': 'problem', 'start': 1294.88, 'duration': 2.279},
#  {'text': 'is focus on improving your skill',
#   'start': 1303.559,
#   'duration': 5.281},
#  {'text': 'set so please avoid this type of',
#   'start': 1306.6,
#   'duration': 4.04},
#  {'text': 'nonsense content and focus on things',
#   'start': 1308.84,
#   'duration': 3.4},
#  {'text': 'that are actually going to impact you',
#   'start': 1310.64,
#   'duration': 3.159},
#  {'text': "there's so much stuff so much", 'start': 1312.24, 'duration': 3.2},
#  {'text': 'distraction in the society right now',
#   'start': 1313.799,
#   'duration': 3.041},
#  {'text': "that if you're not focused you're not",
#   'start': 1315.44,
#   'duration': 3.68},
#  {'text': 'going to get anywhere which brings me to',
#   'start': 1316.84,
#   'duration': 3.959},
#  {'text': 'the final point which is around your',
#   'start': 1319.12,
#   'duration': 4.64},
#  {'text': 'mindset towards', 'start': 1320.799, 'duration': 2.961},
#  {'text': 'wealth and all that stuff I used to do',
#   'start': 1325.64,
#   'duration': 5.279},
#  {'text': 'well in my corporate job also if I would',
#   'start': 1329.12,
#   'duration': 3.76},
#  {'text': 'have stayed in my corporate job I would',
#   'start': 1330.919,
#   'duration': 3.401},
#  {'text': 'have become a partner I would have still',
#   'start': 1332.88,
#   'duration': 3.6},
#  {'text': "made millions of dollars okay that's a",
#   'start': 1334.32,
#   'duration': 3.719},
#  {'text': "fact I'm not saying this to boast I'm",
#   'start': 1336.48,
#   'duration': 4.04},
#  {'text': 'just telling you the', 'start': 1338.039, 'duration': 4.961},
#  {'text': 'reality almost everyone in my class who',
#   'start': 1340.52,
#   'duration': 4.36},
#  {'text': 'has graduated from ncad is making',
#   'start': 1343.0,
#   'duration': 4.039},
#  {'text': 'extremely good money why because to get',
#   'start': 1344.88,
#   'duration': 3.64},
#  {'text': 'into ncad you have to have like very',
#   'start': 1347.039,
#   'duration': 3.281},
#  {'text': 'solid GMAT score you have to do really',
#   'start': 1348.52,
#   'duration': 3.88},
#  {'text': 'well you have to get good jobs whatever',
#   'start': 1350.32,
#   'duration': 3.32},
#  {'text': 'right so I mean it requires a lot of',
#   'start': 1352.4,
#   'duration': 3.2},
#  {'text': 'effort to get into that similarly if you',
#   'start': 1353.64,
#   'duration': 5.96},
#  {'text': 'have gone to a good I good rank all',
#   'start': 1355.6,
#   'duration': 4.0},
#  {'text': 'that what do people', 'start': 1359.96, 'duration': 3.56},
#  {'text': 'do is it beneficial for you can you',
#   'start': 1364.919,
#   'duration': 5.521},
#  {'text': 'learn something from that person can you',
#   'start': 1367.76,
#   'duration': 5.039},
#  {'text': 'understand those Concepts is there Roi',
#   'start': 1370.44,
#   'duration': 5.359},
#  {'text': 'for', 'start': 1372.799, 'duration': 3.0},
#  {'text': 'to a course then of course Like You Know',
#   'start': 1378.559,
#   'duration': 4.48},
#  {'text': 'da G is also a YouTuber some other',
#   'start': 1381.0,
#   'duration': 3.88},
#  {'text': 'educated person is also a YouTuber you',
#   'start': 1383.039,
#   'duration': 3.841},
#  {'text': "can't compare those courses so to say",
#   'start': 1384.88,
#   'duration': 3.76},
#  {'text': 'look at if the other person is selling',
#   'start': 1386.88,
#   'duration': 3.279},
#  {'text': 'you some course or how they have built',
#   'start': 1388.64,
#   'duration': 3.2},
#  {'text': 'their wealth are they sharing something',
#   'start': 1390.159,
#   'duration': 3.76},
#  {'text': 'which is worth learning focus on that',
#   'start': 1391.84,
#   'duration': 5.04},
#  {'text': 'those are more important', 'start': 1393.919, 'duration': 2.961},
#  {'text': 'points another example right there is',
#   'start': 1398.72,
#   'duration': 5.48},
#  {'text': 'onec seconds space on my video then he',
#   'start': 1401.48,
#   'duration': 4.679},
#  {'text': 'makes like one hour video criticizing me',
#   'start': 1404.2,
#   'duration': 3.68},
#  {'text': 'so I have like no interest in arguing',
#   'start': 1406.159,
#   'duration': 3.4},
#  {'text': 'with him basically he was against like',
#   'start': 1407.88,
#   'duration': 3.72},
#  {'text': 'Goa', 'start': 1409.559, 'duration': 5.401},
#  {'text': 'Airbnb airbn this that by I built right',
#   'start': 1411.6,
#   'duration': 6.52},
#  {'text': 'I started buying from 2022 2023 I now',
#   'start': 1414.96,
#   'duration': 4.8},
#  {'text': 'have five properties so to say again not',
#   'start': 1418.12,
#   'duration': 2.799},
#  {'text': 'saying this to B There was an', 'start': 1419.76, 'duration': 3.32},
#  {'text': 'opportunity to do', 'start': 1420.919, 'duration': 4.401},
#  {'text': 'thisn now again there is very difficult',
#   'start': 1423.08,
#   'duration': 3.839},
#  {'text': 'to buy properties in Goa because there',
#   'start': 1425.32,
#   'duration': 3.2},
#  {'text': 'has been so much interest in the last 2',
#   'start': 1426.919,
#   'duration': 3.041},
#  {'text': 'three years that interest was not',
#   'start': 1428.52,
#   'duration': 3.6},
#  {'text': 'created due to me that interest was',
#   'start': 1429.96,
#   'duration': 4.24},
#  {'text': 'created because the property Market in',
#   'start': 1432.12,
#   'duration': 4.28},
#  {'text': 'Goa was going up anyone who invested',
#   'start': 1434.2,
#   'duration': 3.92},
#  {'text': 'made a lot of money so to say including',
#   'start': 1436.4,
#   'duration': 3.759},
#  {'text': 'me and that was a legitimate Arbitrage',
#   'start': 1438.12,
#   'duration': 4.28},
#  {'text': 'so listen to all sides but please do not',
#   'start': 1440.159,
#   'duration': 4.4},
#  {'text': 'believe in pessimism', 'start': 1442.4, 'duration': 4.12},
#  {'text': 'criticize right I mean they will keep on',
#   'start': 1444.559,
#   'duration': 4.161},
#  {'text': 'criticizing you no matter what you do',
#   'start': 1446.52,
#   'duration': 4.84},
#  {'text': 'please differentiate between industry',
#   'start': 1448.72,
#   'duration': 4.88},
#  {'text': 'practitioners learn from them please',
#   'start': 1451.36,
#   'duration': 3.919},
#  {'text': 'avoid people who just keep on talking',
#   'start': 1453.6,
#   'duration': 4.24},
#  {'text': 'negative stuff please avoid people from',
#   'start': 1455.279,
#   'duration': 4.441},
#  {'text': 'whom you cannot learn and execute',
#   'start': 1457.84,
#   'duration': 3.719},
#  {'text': 'anything for example on this video I',
#   'start': 1459.72,
#   'duration': 3.76},
#  {'text': 'would have taught you at least one',
#   'start': 1461.559,
#   'duration': 4.041},
#  {'text': 'education oriented point that you can go',
#   'start': 1463.48,
#   'duration': 4.36},
#  {'text': 'and execute if that is the case then a',
#   'start': 1465.6,
#   'duration': 4.0},
#  {'text': 'press the like Buton and we follow this',
#   'start': 1467.84,
#   'duration': 3.839},
#  {'text': 'Channel and see execute it because when',
#   'start': 1469.6,
#   'duration': 3.84},
#  {'text': 'you execute it that is how your skill',
#   'start': 1471.679,
#   'duration': 3.48},
#  {'text': 'set will go up and that is how you will',
#   'start': 1473.44,
#   'duration': 3.719},
#  {'text': 'prevent yourself from this unpredictable',
#   'start': 1475.159,
#   'duration': 3.601},
#  {'text': 'world that we are living in where there',
#   'start': 1477.159,
#   'duration': 3.76},
#  {'text': 'is no job guarantee anymore and the',
#   'start': 1478.76,
#   'duration': 4.2},
#  {'text': 'situation does not seem to be improving',
#   'start': 1480.919,
#   'duration': 3.12},
#  {'text': "thank you so much for watching and I'll",
#   'start': 1482.96,
#   'duration': 4.28},
#  {'text': 'see you soon', 'start': 1484.039, 'duration': 3.201}]

# %%
result = ""
for i in transcript:
    result += "" + i["text"]

print(result)
# Out:
# so there has been a massive rise of MBAchaiwala and bch chaalis in India nowplease understand that these jobs arenot aspirational in nature these areJobs born out of circumstances so to sayno one does an MBA in order to become achiala seller or a kulcha Wala seller soto say no one does a bch in order tosell snake venom someday this situationis brewing up in India and people areconsidering their role models as elav orDOAbecause and they eventually want tobecome these people on the flip sidethey get to read headlines like these ifyou do a PhDalso what is the point of studyingworking hard like who ended up grindinghis way through gole CEO so what's thepoint of studying when jobs are notthere in the economy so on this videoI'm going to speak about three thingsone is that why is the job situation inIndia or the unemployment situation inIndia is so bad number two is it goingto change anytime soon and third and themost important point is that can you dosomething about it how can you saveyourself in this unemployment bubblethat is getting formed in India forgetabout politicians one party will sellone data another party will sell anotherdata your life will get bbadunnecessarily so it's very important tounderstand take some charge take someaction so this is going to be anaction-packed video I'm honestly goingto share my experiences now you mightsay and all this stuff okay so veryquick background about me guys if you'renew to my channel I just want tocommunicate to you that I have actuallydone corporate jobs I've worked with toptier consulting firms I went to incadwhich is consistently ranked in topthree business schools in the world Iveworked hard I have built startups I donot raise VC fundings currently I run ahedge fund so I have doneokay you should consider me as yournothing like this I'm just telling youthat I believe in the power of EducationI believe that the Youth of our countryneeds better education they need toupskill themselves that's one way ofsaving yourself saving your career it'sabsolutely critical just because youknow me from YouTube does not makeYouTube as 100% of my career if I wereto go back in time 10 years and completemy education well I would do exactly thesame steps that I've done in the past sowith that Spirit I'm going tocommunicate this video I'll be sharp tothe point now one way of dealing withhigh unemployment problem is toconstantly upscale yourself but theproblem is that traditional businessprograms they do not give you practicalinsights but there is a new age businessschool that is addressing this problemso let me introduce you to Partners oftoday's video which is scaler School ofBusiness they are based out of Bangaloreand they offer a management program thatis designed by leaders who have builtbillion doll businesses it exposesstudents to the industry by making themwork on real world projects make theminnovate and build a startup whilestudying and even train them on New AgeTechnologies such as gen Ai andblockchain these technologies willfundamentally change the business andthey educate their students on thesetopics the founding cohort is gettinglaunched on August of 24 theapplications are open and you can applyand get even 100% scholarships check thelinks in description and comment box andapply via these links now with thatlet's move over to the main video sookay so let's go question by questionand let's answer three questions numberone why is the unemployment situationbad in India now many people will saythat you know what you have politicalinclinations you're showing incorrectdata this that so let me just show youthree data points you yourself tell mewhether these are sensible points or notnumber one let me ask you that what hasbeen the growth engine of jobs in thelast 15 20 years automatic answer comesIT jobs that is how cities likeBangalore Hyderabad so to say flourishedbecause a lot of IT jobs came into thepicture that led to the rise of peoplefrom lower middle class to upper middleclass right so that ...
